# %%
# %sh pwd

# %%
spark

# %% [markdown]
# ### Usando comandogos magicos( Comand magic)

# %%
# %python
print("Hola mundo")

# %%
# %sql
SELECT 'Hola mundo ' as Bienvenida

# %%
html = """<h1 style="color:red;text-align:center;font-family:Courier">Bienvendo al mundo de Databricks</h1>"""
displayHTML(html)

# %%
dbutils.fs.ls("dbfs:/")

# %%
# %fs ls

# %%
# %fs ls "dbfs:/databricks-datasets/"

# %%
# %sql
--Para ver en que catalogo estoy posicionado
SELECT current_catalog()

# %%
spark.sql("SELECT current_catalog()").display()

# %%
# %fs mounts
